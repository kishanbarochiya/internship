# %% [markdown]
# ### QUESTION 1

# %% [raw]
# 1. Which of the following constraint requires that there should not be duplicate entries?
#
# A) No Duplicity                 B) Different
# C) Null                         D) Unique

# %% [markdown]
# D) Unique
#
# There is no function like 'No duplicate', 'Different' in SQL. Not null function is used to remove null value presence in data
# UNIQUE function is use to remove duplicate entries in dataset.
#
# For example:
#
#     CREATE TABLE employee (
#     ID int NOT NULL,
#     LastName varchar(255) NOT NULL,
#     FirstName varchar(255) NOT NULL,
#     Age int,
#     Salary int,
#     UNIQUE (ID) #here we will get unique id and not duplicate any employee data
# );

# %% [markdown]
# ### QUESTION 2

# %% [raw]
# 2. Which of the following constraint allows null values in a column?
# A) Primary key               B) Empty Value
# C) Null                      D) None of them

# %% [markdown]
# D) None of them
#
# Primary key strictly not allow any null values. There is no constraint like empty value. Is null constraint is used to check
# null values in dataset.

# %% [markdown]
# ### QUESTION 3

# %% [raw]
# 3. Which of the following statements are true regarding Primary Key?
#
# A) Each entry in the primary key uniquely identifies each entry or row in the table
# B) There can be duplicate values in a primary key column
# C) There can be null values in Primary key
# D) None of the above.

# %% [markdown]
# A)  Each entry in the primary key uniquely identifies each entry or row in the table
#
# As we know that Primary key is important to concat or compare different table so there is no place for null values.
# Primary key column have unique value for all rows so there is no duplication allowed for any rows.

# %% [markdown]
# ### QUESTION 4

# %% [raw]
# 4. Which of the following statements are true regarding Unique Key?
#
# A) There should not be any duplicate entries
# B) Null values are not allowed
# C) Multiple columns can make a single unique key together
# D) All of the above

# %% [markdown]
# A) There should not be any duplicate entries
#
# There is main difference between primary and unique key is about null values so in Unique key Null value allowed while both are
# for uniqueness of column so here, option A is right that there is not any duplicate entries.

# %% [markdown]
# ### QUESTION 5

# %% [raw]
# 5. Which of the following is/are example of referential constraint?
#
# A) Not Null          B) Foreign Key
# C) Referential key   D) All of them

# %% [markdown]
# D) All of them
#
# Not null constraint enforce column to not contain null values. Foreign key is secondry key to relate 2 tables and regerential key
# is used for reference two table as per name. so here all options are example of referential constraint.

# %%
#IMAGE REFERENCE FOR QUESTION NO 6 TO QUESTION NO 13

from PIL import Image
im = Image.open("222.JPG")
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=712x400 at 0x245B8F032E0>

# %% [markdown]
# ### QUESTION 6

# %% [raw]
# 6. How many foreign keys are there in the Supplier table?
#     A) 0                   B) 3
#     C) 2                   D) 1

# %% [markdown]
# A) 0
#
# Supplier table is parent table while Delivery and Product tables are child table so we can say that Supplier table have primary key

# %% [markdown]
# ### QUESTION 7

# %% [raw]
# 7. The type of relationship between Supplier table and Product table is:
#
#     A) one to many    B) many to one
#     C) one to one     D) many to many

# %% [markdown]
# A) one to many
#
# As we know that one supplier can supply many prodcut so it is one to many relationship. based on data it might be become
# many to many where one supplier can supply many product and multiple product supplied by multiple supplier.

# %% [markdown]
# ### QUESTION 8

# %% [raw]
# 8. The type of relationship between Order table and Headquarter table is:
#     A) one to many             B) many to one
#     C) one to one              D) many to many

# %% [markdown]
#  B) many to one
#
# Here, we can mark that particular order have only one headquarter id but one headquarter id have many order id. so it will
# become a many to one relationship

# %% [markdown]
# ### QUESTION 9

# %% [raw]
# 9. Which of the following is a foreign key in Delivery table?
#
# A) delivery id           B) supplier id
# C) delivery date         D) None of them

# %% [markdown]
# A) delivery id
#
# In general concept, primary key of parent table is foreign key for child table and here, delivery table have all 3 same column as supplier table but thing is that from it only delivery id have all unique value because delivery date may be same for some cases, supplier id may be same if product is supplied by same supplier so here, foreign key is delivery id

# %% [markdown]
# ### QUESTION 10

# %% [raw]
# 10. The number of foreign keys in order details is:
#
#     A) 0          B) 1
#     C) 3          D) 2

# %% [markdown]
# D) 2
#
# From order details delivery table, 'order id' is primary key which will become foreign key for order table and in product table
# product id is primary key which will become foreign key for order table so here we have total 2 foreign key.

# %% [markdown]
# ### QUESTION 11

# %% [raw]
# 11. The type of relationship between Order Detail table and Product table is:
#
#     A) one to many         B) many to one
#     C) one to one          D) many to many

# %% [markdown]
# D) many to many
#
# One order id have multiple product id as one can order multiple product in same order.
# one product id have multiple order id as many can order one product
# thus it will become many to many relationship.

# %% [markdown]
# ### QUESTION 12

# %% [raw]
# 12. DDL statements perform operation on which of the following database objects?
#
#     A) Rows of table      B) Columns of table
#     C) Table              D) None of them

# %% [markdown]
# C) Table
#
# DDL statments is used to create,alter and drop objects in table. analyze the information from table,cluster or index.

# %% [markdown]
# ### QUESTION 13

# %% [raw]
# 13. Which of the following statement is used to enter rows in a table?
#
#     A) Insert in to           B) Update
#     C) Enter into             D) Set Row

# %% [markdown]
# A) Insert in to
#
# Insert command is use for enter rows in table.
# example is,
#
# INSERT INTO EMPLOYEE [Age, Married, Salary]
#
# VALUES (28,Yes,45300);

# %% [markdown]
# ### QUESTION 14

# %% [raw]
# 14. Which of the following is/are entity constraints in SQL?
#
#     A) Duplicate    B) Unique
#     C) Primary Key  D) Null

# %% [markdown]
# B) Unique  & C) Primary Key
#
# Entity constraints is used to identify the row or record of table uniquely.
#
# We know that primary key have always unique value while UNIQUE contraints allow us to get unique value for each obeservation.

# %% [markdown]
# ### QUESTION 15

# %% [raw]
# 15. Which of the following statements is an example of semantic Constraint?
#
#     A) A blood group can contain one of the following values - A, B, AB and O.
#     B) A blood group can only contain characters
#     C) A blood group cannot have null values
#     D) Two or more donors can have same blood group

# %% [markdown]
# A) A blood group can contain one of the following values - A, B, AB and O.
#
# B) A blood group can only contain characters
#
# a semantic constraint is a relationship between two parts of a proposition such that the meaning of one part constrains what the other part may be,
# blood group is single value for particular person so A is right that it contain only one from it while blood group is from that
# only 4 and that 4 are contain charater only so option B) is also semanstic constraint.
